# %%
import requests
import json
import requests
url="https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018"
headers = {"authorization": "token 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"}
json = requests.get(url,headers =headers).json()

# %%
url0="https://api.github.com/repos/ironhack-datalabs/forks_url"
headers = {"authorization": "token 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"}
json = requests.get(url,headers =headers).json()
for k in json:
    print(k)
# Out:
# id
# node_id
# name
# full_name
# private
# owner
# html_url
# description
# fork
# url
# forks_url
# keys_url
# collaborators_url
# teams_url
# hooks_url
# issue_events_url
# events_url
# assignees_url
# branches_url
# tags_url
# blobs_url
# git_tags_url
# git_refs_url
# trees_url
# statuses_url
# languages_url
# stargazers_url
# contributors_url
# subscribers_url
# subscription_url
# commits_url
# git_commits_url
# comments_url
# issue_comment_url
# contents_url
# compare_url
# merges_url
# archive_url
# downloads_url
# issues_url
# pulls_url
# milestones_url
# notifications_url
# labels_url
# releases_url
# deployments_url
# created_at
# updated_at
# pushed_at
# git_url
# ssh_url
# clone_url
# svn_url
# homepage
# size
# stargazers_count
# watchers_count
# language
# has_issues
# has_projects
# has_downloads
# has_wiki
# has_pages
# has_discussions
# forks_count
# mirror_url
# archived
# disabled
# open_issues_count
# license
# allow_forking
# is_template
# ...

# %%
for k in json:
    print(k)
# Out:
# id
# node_id
# name
# full_name
# private
# owner
# html_url
# description
# fork
# url
# forks_url
# keys_url
# collaborators_url
# teams_url
# hooks_url
# issue_events_url
# events_url
# assignees_url
# branches_url
# tags_url
# blobs_url
# git_tags_url
# git_refs_url
# trees_url
# statuses_url
# languages_url
# stargazers_url
# contributors_url
# subscribers_url
# subscription_url
# commits_url
# git_commits_url
# comments_url
# issue_comment_url
# contents_url
# compare_url
# merges_url
# archive_url
# downloads_url
# issues_url
# pulls_url
# milestones_url
# notifications_url
# labels_url
# releases_url
# deployments_url
# created_at
# updated_at
# pushed_at
# git_url
# ssh_url
# clone_url
# svn_url
# homepage
# size
# stargazers_count
# watchers_count
# language
# has_issues
# has_projects
# has_downloads
# has_wiki
# has_pages
# has_discussions
# forks_count
# mirror_url
# archived
# disabled
# open_issues_count
# license
# allow_forking
# is_template
# ...

# %%
url2="https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/languages"
headers = {"authorization": "token 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"}
json2 = requests.get(url2,headers =headers).json()
json2
# Out:
# {'Jupyter Notebook': 1134241, 'HTML': 498316, 'Python': 8691}

# %%
for k in json2:
    print(k)
# Out:
# Jupyter Notebook
# HTML
# Python

# %%
url="https://api.github.com/repos/Sandra-Lor/test"
headers = {"authorization": "token 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"}
json = requests.get(url,headers =headers).json()
json
# Out:
# {'id': 670567157,
#  'node_id': 'R_kgDOJ_gK9Q',
#  'name': 'test',
#  'full_name': 'Sandra-Lor/test',
#  'private': False,
#  'owner': {'login': 'Sandra-Lor',
#   'id': 135267050,
#   'node_id': 'U_kgDOCBAC6g',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/135267050?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Sandra-Lor',
#   'html_url': 'https://github.com/Sandra-Lor',
#   'followers_url': 'https://api.github.com/users/Sandra-Lor/followers',
#   'following_url': 'https://api.github.com/users/Sandra-Lor/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Sandra-Lor/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Sandra-Lor/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Sandra-Lor/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Sandra-Lor/orgs',
#   'repos_url': 'https://api.github.com/users/Sandra-Lor/repos',
# ...

# %%
url6= "https://api.github.com/repos/Sandra-Lor/test"
headers = {"authorization": "token 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"}
json = requests.get(url6,headers =headers).json()
json2 = requests.get(json["commits_url"].replace("{/sha}",""),headers=headers).json()

# %%
len(json2)
# Out:
# 3
